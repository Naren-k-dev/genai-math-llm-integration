# %%
import os
import json
import math
import openai

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
def calculate_cylinder_volume(radius, height):
    """Calculate the volume of a cylinder"""

    volume = math.pi * radius * radius * height

    result = {
        "radius": radius,
        "height": height,
        "volume": round(volume, 2),
        "unit": "cubic units"
    }

    return json.dumps(result)

# %%
functions = [
    {
        "name": "calculate_cylinder_volume",
        "description": "Calculate the volume of a cylinder",
        "parameters": {
            "type": "object",
            "properties": {
                "radius": {
                    "type": "number",
                    "description": "Radius of the cylinder"
                },
                "height": {
                    "type": "number",
                    "description": "Height of the cylinder"
                }
            },
            "required": ["radius", "height"]
        }
    }
]

# %%
messages = [
    {
        "role": "user",
        "content": "Calculate the volume of a cylinder with radius 3 and height 10"
    }
]

# %%
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
    functions=functions,
    function_call="auto"
)

# %%
print(response)
# Out:
# {
#   "id": "chatcmpl-DeIAJpcinGqGJNWQeQt6dmW2EzNVa",
#   "object": "chat.completion",
#   "created": 1778495319,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": null,
#         "function_call": {
#           "name": "calculate_cylinder_volume",
#           "arguments": "{\"radius\":3,\"height\":10}"
#         },
#         "refusal": null,
#         "annotations": []
#       },
#       "logprobs": null,
#       "finish_reason": "function_call"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 78,
#     "completion_tokens": 20,
#     "total_tokens": 98,
#     "prompt_tokens_details": {
#       "cached_tokens": 0,
#       "audio_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0,
#       "audio_tokens": 0,
#       "accepted_prediction_tokens": 0,
#       "rejected_prediction_tokens": 0
#     }
#   },
#   "service_tier": "default",
#   "system_fingerprint": null
# }

# %%
message = response["choices"][0]["message"]

if message.get("function_call"):

    function_name = message["function_call"]["name"]

    arguments = json.loads(message["function_call"]["arguments"])

    radius = arguments["radius"]
    height = arguments["height"]

    result = calculate_cylinder_volume(radius, height)
    
    print("Name: Narendran K\n Register Number : 212223230135")
    print(result)
# Out:
# Name: Narendran K
#  Register Number : 212223230135
# {"radius": 3, "height": 10, "volume": 282.74, "unit": "cubic units"}
